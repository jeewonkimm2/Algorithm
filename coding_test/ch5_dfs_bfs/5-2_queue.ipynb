# %%
from collections import deque

queue = deque()

# %%
queue.append(5)
queue.append(2)
queue.append(3)
queue.append(7)
queue.popleft()
queue.append(1)
queue.append(4)
queue.popleft()
# Out:
# 2

# %%
print(queue)
# Out:
# deque([3, 7, 1, 4])

# %%
queue.reverse()
print(queue)
# Out:
# deque([4, 1, 7, 3])

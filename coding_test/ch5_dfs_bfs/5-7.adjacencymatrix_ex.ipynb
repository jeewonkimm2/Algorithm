# %%
graph = [[] for _ in range(3)]

graph
# Out:
# [[], [], []]

# %%
graph[0].append((1,7))
graph[0].append((2,5))

# %%
graph
# Out:
# [[(1, 7), (2, 5)], [], []]

# %%
graph[1].append((0,7))
graph[2].append((0,5))

# %%
graph
# Out:
# [[(1, 7), (2, 5)], [(0, 7)], [(0, 5)]]
